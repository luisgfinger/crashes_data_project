# %%
import pandas as pd

df = pd.read_csv('../data/bronze/crashes/full/raw_20260306/*.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('../data/bronze/crashes/full/raw_20260306/*.csv')
#
# File ~\Downloads\crashes-data-project\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %%
df.head()
# Out:
#    UNIQUE_ID  COLLISION_ID  CRASH_DATE CRASH_TIME  \
# 0   20364177       4594551  01/01/2023       9:23
# 1   20364825       4594751  01/01/2023      13:38
# 2   20364178       4594551  01/01/2023       9:23
# 3   20369709       4597028  01/01/2023      20:55
# 4   20364064       4594437  01/01/2023       4:25
#
#                              VEHICLE_ID STATE_REGISTRATION VEHICLE_TYPE  \
# 0  f0cf3446-8381-4583-8d57-2c16f4614209                 NY        Sedan
# 1  5e3005ce-ffe2-4412-bab4-b19eb295b71d                 NY        Sedan
# 2  c99c3925-d18e-4abe-89ee-e822f0db2589                 NY        Sedan
# 3  c4043add-3e60-48b1-8c8c-53c6d8449afa                 NY        Sedan
# 4  f9d98daf-1754-4169-bc6d-94e6cd4f1dc0                 NY        Sedan
#
#     VEHICLE_MAKE  VEHICLE_MODEL  VEHICLE_YEAR  ...             PRE_CRASH  \
# 0  HOND -CAR/SUV            NaN        2914.0  ...                Parked
# 1            NaN            NaN           NaN  ...      Making Left Turn
# ...

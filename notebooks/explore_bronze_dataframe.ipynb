# %%
import pandas as pd

df = pd.read_csv('../data/bronze/vehicles/full/vehicles_raw_20260221.csv')
# Out:
# C:\Users\finge\AppData\Local\Temp\ipykernel_2876\2547852492.py:3: DtypeWarning: Columns (0: VEHICLE_OCCUPANTS) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/bronze/vehicles/full/vehicles_raw_20260221.csv')

# %%
df["VEHICLE_MODEL"].unique()
# Out:
# array([nan])

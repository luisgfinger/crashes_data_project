# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/silver/vehicles/v1/run_date=*/*.parquet')
    LIMIT 10
""").df()
# Out:
#    unique_id collision_id                         vehicle_type  \
# 0   20364178      4594551                                Sedan
# 1   20369709      4597028                                Sedan
# 2   20364064      4594437                                Sedan
# 3   20365312      4595216                                   PK
# 4   20364170      4594641  Station Wagon/Sport Utility Vehicle
# 5   20364800      4594775                                Sedan
# 6   20365342      4595088  Station Wagon/Sport Utility Vehicle
# 7   20364019      4594438                                Sedan
# 8   20364079      4594571                                Sedan
# 9   20364769      4594810                                Sedan
#
#      vehicle_make  vehicle_year   run_date
# 0   HYUN -CAR/SUV          2016 2026-02-27
# 1   MERZ -CAR/SUV          2013 2026-02-27
# 2   TOYT -CAR/SUV          2000 2026-02-27
# 3  FORD-TRUCK/BUS          2016 2026-02-27
# 4   ACUR -CAR/SUV          2016 2026-02-27
# ...

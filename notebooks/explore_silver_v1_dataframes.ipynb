# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/silver/vehicles/v1/run_date=*/*.parquet')
    LIMIT 1000
""").df()
# Out:
#      unique_id                         vehicle_type     vehicle_make  \
# 0     20364825                                Sedan              NaN
# 1     20364178                                Sedan    HYUN -CAR/SUV
# 2     20369709                                Sedan    MERZ -CAR/SUV
# 3     20364064                                Sedan    TOYT -CAR/SUV
# 4     20365312                                   PK   FORD-TRUCK/BUS
# ..         ...                                  ...              ...
# 995   20364900  Station Wagon/Sport Utility Vehicle    TOYT -CAR/SUV
# 996   20365547                                Sedan    CHEV -CAR/SUV
# 997   20365339                                  NaN              NaN
# 998   20814998  Station Wagon/Sport Utility Vehicle    NISS -CAR/SUV
# 999   20814995                                Moped  JIANGSU BAODIAO
#
#     vehicle_model  vehicle_year   run_date
# 0            None          <NA> 2026-02-26
# 1            None          2016 2026-02-26
# ...

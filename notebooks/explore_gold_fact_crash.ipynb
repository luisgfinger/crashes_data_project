# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/gold/fact/fact_crash/run_date=*/*.parquet')
    LIMIT 10
""").df()
# Out:
#    collision_id  date_key crash_date crash_time  number_of_persons_injured  \
# 0       4599014  20230101 2023-01-01       None                          0
# 1       4598137  20230101 2023-01-01       None                          0
# 2       4599015  20230101 2023-01-01       None                          1
# 3       4599499  20230101 2023-01-01       None                          0
# 4       4599239  20230101 2023-01-01       None                          0
# 5       4599214  20230101 2023-01-01       None                          0
# 6       4599827  20230101 2023-01-01       None                          0
# 7       4600461  20230101 2023-01-01       None                          0
# 8       4600840  20230101 2023-01-01       None                          0
# 9       4600946  20230101 2023-01-01       None                          0
#
#    number_of_persons_killed  number_of_pedestrians_injured  \
# 0                         0                              0
# ...

# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/gold/dim/dim_vehicle/*.parquet')
    LIMIT 10
""").df()
# Out:
#     vehicle_dim_id               vehicle_make  \
# 0   38718848805153           (1 AXLE TRAILER)
# 1   95348558475317  (MTA BUS) ARTIC NEW FLYER
# 2  151001204194191                   -CAR/SUV
# 3   35539618936576                       /GMC
# 4   95659472624777                    15 NOVA
# 5  279315944441657                        150
# 6  279016545238151                        150
# 7    2802027766685                       1500
# 8  197871803196619                 18 WHEELER
# 9   13427844164159           18 WHEELER TRUCK
#
#                           vehicle_type
# 0                              TRAILER
# 1                                  BUS
# 2  STATION WAGON/SPORT UTILITY VEHICLE
# 3                                   TK
# 4                                  BUS
# 5                                MOPED
# 6                           MOTORCYCLE
# 7                        PICK-UP TRUCK
# 8                                  VAN
# 9                     BULK AGRICULTURE

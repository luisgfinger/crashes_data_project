# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/gold/v1/dim/dim_vehicle/*.parquet')
    LIMIT 10
""").df()
# Out:
#     vehicle_dim_id    vehicle_make                         vehicle_type
# 0  124757119462563   ACUR -CAR/SUV                                SEDAN
# 1  160597857556774   ACUR -CAR/SUV  STATION WAGON/SPORT UTILITY VEHICLE
# 2   62356180935774   ALFA -CAR/SUV                                SEDAN
# 3  131954549951053   AUDI -CAR/SUV                                SEDAN
# 4  182610437174906   AUDI -CAR/SUV  STATION WAGON/SPORT UTILITY VEHICLE
# 5  186913044287405  BLUI-TRUCK/BUS                                  BUS
# 6  272901834115714    BMW -CAR/SUV                                SEDAN
# 7   23681157110923    BMW -CAR/SUV  STATION WAGON/SPORT UTILITY VEHICLE
# 8  269532282179890   BUIC -CAR/SUV  STATION WAGON/SPORT UTILITY VEHICLE
# 9   90829949065195   CHEV -CAR/SUV                        PICK-UP TRUCK

# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/gold/crash_summary/v1/full/run_date=*/*.parquet')
    LIMIT 10
""").df()
# Out:
#    collision_id  total_vehicles  crash_year        main_contributing_factor  \
# 0       4594551               3        2023                     Unspecified
# 1       4594751               1        2023                    Unsafe Speed
# 2       4597028               3        2023                     Unspecified
# 3       4594437               1        2023  Driver Inattention/Distraction
# 4       4595216               1        2023                     Unspecified
# 5       4594641               2        2023                     Unspecified
# 6       4594775               2        2023             Alcohol Involvement
# 7       4594752               1        2023  Passing or Lane Usage Improper
# 8       4595088               1        2023                Backing Unsafely
# 9       4594438               2        2023             Alcohol Involvement
#
#     run_date
# 0 2026-03-03
# 1 2026-03-03
# 2 2026-03-03
# 3 2026-03-03
# 4 2026-03-03
# 5 2026-03-03
# 6 2026-03-03
# 7 2026-03-03
# ...

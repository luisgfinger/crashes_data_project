# %%
import duckdb

duckdb.sql("""
    SELECT *
    FROM parquet_scan('../data/gold/crash_summary/v1/full/crash_year=2026/*.parquet')
    LIMIT 10
""").df()
# Out:
#    collision_id  total_vehicles        main_contributing_factor  crash_year
# 0       4869919               0                     Unspecified        2026
# 1       4873382               1                     Unspecified        2026
# 2       4868753               2                     Unspecified        2026
# 3       4870428               1  Driver Inattention/Distraction        2026
# 4       4868798               2                     Unspecified        2026
# 5       4870953               0  Driver Inattention/Distraction        2026
# 6       4868813               1                     Unspecified        2026
# 7       4869587               1  Driver Inattention/Distraction        2026
# 8       4868850               1                     Unspecified        2026
# 9       4868915               2             Alcohol Involvement        2026
